# %%
# %matplotlib inline
# %config Completer.use_jedi = False

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
train_data = pd.read_excel("../../data/unzipped/Train.xlsx", skiprows=range(1,2), index_col=0)

# %%
train_data.head()
# Out:
#          Диффузный индекс цен на выпускаемую продукцию, ожидаемые изменения   \
# 2003m01                                                 74
# 2003m02                                                 78
# 2003m03                                                 84
# 2003m04                                                 83
# 2003m05                                                 79
#
#          Диффузный индекс цен на покупаемую продукцию, ожидаемые изменения   \
# 2003m01                                                 93
# 2003m02                                                 95
# 2003m03                                                 98
# 2003m04                                                 95
# 2003m05                                                 94
#
#          Диффузный индекс заработной платы, ожидаемые изменения   \
# 2003m01                                                 61
# 2003m02                                                 66
# 2003m03                                                 72
# 2003m04                                                 70
# 2003m05                                                 76
#
#          Диффузный индекс занятости, ожидаемые изменения   \
# 2003m01                                                40
# 2003m02                                                37
# 2003m03                                                45
# 2003m04                                                40
# 2003m05                                                43
#
#          Диффузный индекс выпуска, ожидаемые изменения   \
# 2003m01                                              44
# 2003m02                                              49
# 2003m03                                              56
# 2003m04                                              66
# 2003m05                                              66
#
#          Диффузный индекс закупок оборудования, ожидаемые изменения   \
# 2003m01                                                 28
# 2003m02                                                 30
# 2003m03                                                 29
# 2003m04                                                 38
# 2003m05                                                 33
#
#          Диффузный индекс финансового состояния, ожидаемые изменения   \
# 2003m01                                                 47
# 2003m02                                                 53
# 2003m03                                                 51
# 2003m04                                                 59
# 2003m05                                                 63
#
#          Диффузный индекс портфеля заказов, ожидаемые изменения   \
# 2003m01                                                 44
# 2003m02                                                 56
# 2003m03                                                 61
# 2003m04                                                 69
# 2003m05                                                 68
#
#          Диффузный индекс задолженности банкам, ожидаемые изменения   \
# 2003m01                                                 22
# 2003m02                                                 18
# 2003m03                                                 25
# 2003m04                                                 23
# 2003m05                                                 23
#
#          Производство скота и птицы, тыс.тонн   ...  \
# 2003m01                               6.269096  ...
# 2003m02                               6.320768  ...
# 2003m03                               6.361302  ...
# 2003m04                               6.269096  ...
# 2003m05                               6.177944  ...
#
#          Среднемесячная пенсия, руб.  Реальная пенсия  MIACR  \
# 2003m01                     7.288791         0.000000  6.331
# 2003m02                     7.313953         0.008960  2.514
# 2003m03                     7.314153        -0.001091  2.625
# 2003m04                     7.382809         0.057178  1.888
# 2003m05                     7.382809         0.049146  1.308
#
#          Ставка по краткосрочным кредитам, население  \
# 2003m01                                         21.5
# 2003m02                                         22.2
# 2003m03                                         18.3
# 2003m04                                         20.0
# 2003m05                                         23.1
#
#          Ставка по долгосрочным кредитам, население  \
# 2003m01                                        18.9
# 2003m02                                        17.8
# 2003m03                                        19.9
# 2003m04                                        21.3
# 2003m05                                        21.5
#
#          Ставка по краткосрочным кредитам, фирмы  \
# 2003m01                                     14.5
# 2003m02                                     14.1
# 2003m03                                     13.3
# 2003m04                                     13.4
# 2003m05                                     12.5
#
#          Ставка по долгосрочным кредитам, фирмы  \
# 2003m01                                    17.3
# 2003m02                                    19.6
# 2003m03                                    16.4
# 2003m04                                    14.9
# 2003m05                                    15.0
#
#          Краткосрочные кредиты и прочие средства нефинансовым организациям, млрд.руб  \
# 2003m01                                           6.993658
# 2003m02                                           7.019476
# 2003m03                                           7.031299
# 2003m04                                           7.048821
# 2003m05                                           7.076400
#
#          Долгосрочные кредиты и прочие средства нефинансовым организациям, млрд.руб  \
# 2003m01                                           6.290272
# 2003m02                                           6.298398
# 2003m03                                           6.325613
# 2003m04                                           6.343001
# 2003m05                                           6.371099
#
#          Цена Urals, долл/бар
# 2003m01              3.383413
# 2003m02              3.420624
# 2003m03              3.363693
# 2003m04              3.130242
# 2003m05              3.210488
#
# [5 rows x 69 columns]

# %%
train_data.values[:, 0]
# Out:
# array([74., 78., 84., 83., 79., 75., 74., 76., 74., 71., 77., 72., 80.,
#        81., 85., 76., 73., 79., 74., 74., 69., 74., 73., 73., 79., 85.,
#        81., 76., 73., 70., 67., 67., 69., 74., 70., 68., 77., 82., 79.,
#        77., 69., 69., 67., 73., 73., 79., 74., 74., 80., 84., 85., 82.,
#        73., 73., 75., 72., 78., 75., 79., 77., 82., 85., 89., 81., 81.,
#        77., 74., 75., 74., 75., 72., 69., 67., 57., 57., 61., 58., 55.,
#        53., 52., 53., 58., 55., 58., 64., 69., 67., 76., 64., 67., 65.,
#        68., 66., 67., 66., 62., 75., 80., 84., 81., 71., 70., 67., 69.,
#        71., 68., 67., 61., 67., 67., 74., 68., 63., 61., 64., 67., 66.,
#        66., 63., 69., 70., 73., 75., 63., 68., 60., 57., 65., 64., 56.,
#        55., 58., 64., 67., 69., 63., 58., 63., 63., 58., 63., 67., 63.,
#        66., 81., 78., 85., 81., 74., 66., 60., 53., 60., 57., 65., 64.])

# %%
class MetaModel:
    def __init__(self, window_size, normalizer, base_model, dynamic_model):
        self.window_size = window_size
        self.normalizer = normalizer
        self.base_model = base_model
        self.dynamic_model = dynamic_model
    def fit(self, X):
        assert len(X.shape) == 2
        X = self.normalizer(X)
        params = self.dynamic_model(X)
        self.base_model.fit(X, params)
    def predict(self, X):
        assert len(X.shape) == 1
        X = self.normalizer(X)
        params = self.base_model.predict(X)
        curve = self.dynamic_model.next_point(X, params)
        return self.

# %%
plt.plot(train_data.values[:, 0])

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
X = train_data.values[:, 0]

# %%
decompose_result = seasonal_decompose(X, model="additive", period=12)

trend = decompose_result.trend
seasonal = decompose_result.seasonal
residual = decompose_result.resid

decompose_result.plot();

# %%
from sklearn.linear_model import LinearRegression

# %%
wo_seasons = X - seasonal
ids = np.arange(len(X)).reshape(-1,1)

# %%
trend_model = LinearRegression().fit(ids, wo_seasons)

# %%
trend_model.coef_, trend_model.intercept_
# Out:
# (array([-0.08832008]), 77.12044706775)

# %%
diff = wo_seasons - trend_model.predict(ids)

# %%
diff_norm = (diff - np.mean(diff)) / np.std(diff)

# %%
plt.plot(np.diff(diff_norm))

# %%
plt.plot(trend_model.predict(ids))

# %%
from statsmodels.tsa.stattools import adfuller

# %%
result = adfuller(diff_norm)

# %%
result
# Out:
# (-3.369446287684339,
#  0.012045602952674067,
#  1,
#  154,
#  {'1%': -3.473542528196209,
#   '5%': -2.880497674144038,
#   '10%': -2.576878053634677},
#  274.0212710268156)

# %%
X = train_data.values[:, 18]
y = list(np.where(np.isnan(X))[0]) + [-1]
np.max(y)
# Out:
# 23

# %%
window = 12 * 1

# %%
def remove_nan_prefix(X):
    last_nan = np.max(list(np.where(np.isnan(X))[0]) + [-1])
    X = X[last_nan + 1:]
    return X

# %%
class Normalizer:
    def transform(self, X):
        X = remove_nan_prefix(X)
        r = seasonal_decompose(X, model="additive", period=12)
        trend = X - r.seasonal
        mean = np.mean(trend)
        std = np.std(trend)
        trend_norm = (trend - mean) / std
        self.seasonal = r.seasonal
        self.mean = mean
        self.std = std
        return trend_norm
    def inverse(self, X):
        X *= self.std
        X += self.mean
        seasons = np.tile(self.seasonal, 2)[:len(X)]
        X += seasons
        return X

# %%
seq = train_data.values[:, 35]
normalizer = Normalizer()
subSeq = seq[-window - 1:]
origSubSeq = subSeq
subSeq = normalizer.transform(subSeq)
plt.plot(subSeq)
T0 = subSeq[0]
subSeq = np.diff(subSeq)
x = subSeq[-window-1:].reshape(1,-1)
#         y = base_model.predict(x)[0]
y = x[0][-1]
subSeq = [T0] + list(subSeq) + [y]
subSeq = np.cumsum(subSeq)
subSeq = normalizer.inverse(subSeq)
assert np.mean((subSeq[:-1] - origSubSeq) ** 2) < 1e-6, (subSeq, origSubSeq)
seq = np.append(seq, subSeq[-1])
plt.plot(origSubSeq)
print(origSubSeq, subSeq)
# Out:
# [0.42333411 0.27251122 0.28443979 0.34835312 0.35532873 0.35432823
#  0.38485744 0.36158881 0.36458432 0.35957178 0.36853152 0.39419927
#  0.4505796  0.30323901 0.34149772 0.38838131 0.3853768  0.3873748
#  0.41790401 0.3956584  0.38358582 0.38558382 0.41319899 0.43398153
#  0.48467464 0.36024456 0.37513318 0.39982579 0.4147144  0.39960076
#  0.41842252 0.42241454 0.42441254 0.4194     0.44213949 0.44712703
#  0.49114391 0.3835587  0.40336133 0.43389053 0.43887808 0.40944927
#  0.42728918 0.43227673 0.4382588  0.44424087 0.4541912  0.4541912
#  0.517166   0.39046835 0.39346385 0.43075964 0.41666072 0.38413752
#  0.42046945 0.42246746 0.42146695 0.42943512 0.43740329 0.43540129
#  0.49461315] [0.42333411 0.27251122 0.28443979 0.34835312 0.35532873 0.35432823
#  0.38485744 0.36158881 0.36458432 0.35957178 0.36853152 0.39419927
#  0.4505796  0.30323901 0.34149772 0.38838131 0.3853768  0.3873748
#  0.41790401 0.3956584  0.38358582 0.38558382 0.41319899 0.43398153
#  0.48467464 0.36024456 0.37513318 0.39982579 0.4147144  0.39960076
#  0.41842252 0.42241454 0.42441254 0.4194     0.44213949 0.44712703
#  0.49114391 0.3835587  0.40336133 0.43389053 0.43887808 0.40944927
#  0.42728918 0.43227673 0.4382588  0.44424087 0.4541912  0.4541912
#  0.517166   0.39046835 0.39346385 0.43075964 0.41666072 0.38413752
#  0.42046945 0.42246746 0.42146695 0.42943512 0.43740329 0.43540129
#  0.49461315 0.5009902 ]

# %%
import tqdm

X_normed = []
for i in tqdm.tqdm(np.arange(train_data.shape[1]), position=0):
    X = train_data.values[:, i][:-window]
    X = Normalizer().transform(X)
    for j in range(len(X) - window - 2):
        sample = X[j:j+ window+2]
#         sample = np.diff(sample)
        X_normed.append(sample)
# Out:
# 100%|█████████████████████████████████████████| 69/69 [00:00<00:00, 1162.76it/s]

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
base_model = KNeighborsRegressor()

# %%
base_model.fit([x[:-1] for x in X_normed], [x[-1] for x in X_normed])
# Out:
# KNeighborsRegressor()

# %%
from sklearn.manifold import TSNE

# %%
tsne = TSNE(verbose=1)

# %%
res = tsne.fit_transform([x[:-1] for x in X_normed])
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 8874 samples in 0.011s...
# [t-SNE] Computed neighbors for 8874 samples in 0.714s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 8874
# [t-SNE] Computed conditional probabilities for sample 2000 / 8874
# [t-SNE] Computed conditional probabilities for sample 3000 / 8874
# [t-SNE] Computed conditional probabilities for sample 4000 / 8874
# [t-SNE] Computed conditional probabilities for sample 5000 / 8874
# [t-SNE] Computed conditional probabilities for sample 6000 / 8874
# [t-SNE] Computed conditional probabilities for sample 7000 / 8874
# [t-SNE] Computed conditional probabilities for sample 8000 / 8874
# [t-SNE] Computed conditional probabilities for sample 8874 / 8874
# [t-SNE] Mean sigma: 0.139147
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 76.890144
# [t-SNE] KL divergence after 1000 iterations: 1.455103

# %%
X_normed[0].shape
# Out:
# (14,)

# %%
plt.plot(res[:, 0], res[:,1], '*')

# %%
class ConstModel:
    def predict(self, X):
        return [X[0][-1]]

# %%
def predict_for_seq(seq, steps, model):
    assert len(seq.shape) == 1, seq.shape[0] >= window + 1
    normalizer = Normalizer()
    seq = normalizer.transform(seq)
    for i in np.arange(steps):
        subSeq = seq[-window - 1:]
        origSubSeq = subSeq
        x = subSeq[-window-1:].reshape(1,-1)
        y = model.predict(x)[0]
        subSeq = list(subSeq) + [y]
        assert np.mean((subSeq[:-1] - origSubSeq) ** 2) < 1e-6, (subSeq, origSubSeq)
        seq = np.append(seq, subSeq[-1])
        plt.show()
    seq = normalizer.inverse(seq)
    return seq

# %%
from sklearn.metrics import r2_score, mean_squared_error

# %%
class Task:
    def __init__(self, history, orig, pred, period=12):
        assert period in [4,12]
        self.history = history
        self.orig = orig
        self.pred = pred
        self.period = period

# %%
from scipy.stats import norm

def wmsfe(tasks):
    hm = np.array([len(t.orig) for t in tasks])
    km = np.sum(hm)
    scores = []
    for t in tasks:
        assert t.orig.shape == t.pred.shape
        disp = np.var(t.history[t.period:] - t.history[:-t.period])
        score = np.sum((t.orig - t.pred) ** 2 / (np.arange(len(t.pred)) + 1)) / disp
        scores.append(score)
    return np.sum(scores) / km, scores / hm

def total(wmsfes):
    score = 0
    alpha = 12
    for m in wmsfes:
        score += (1.8 - 1.6 / (1 + np.exp(-alpha * m)))
    return score / len(wmsfes)

def p_val(x):
    return 2 * min(norm.cdf(-x), norm.cdf(x))

def z_test(res1, res2):
    res2 = np.log(res2)
    res1 = np.log(res1)
    delta = res2 - res1
    mu_z = np.mean(delta)
    sigma = np.std(delta)
    z = mu_z / sigma * T ** 0.5
    p = p_val(z)
    win_rate = np.mean(res1 <= res2) 
    return {"p_value":p, "mu": mu_z, "sigma": sigma, "win_rate": win_rate}

# %%
def measure_on_all_train_data(model, offset=36):
    mse = 0
    N = train_data.shape[1]
    tasks = []
    for t in np.arange(N):
        history = remove_nan_prefix(train_data.values[:, t])
        window_data = history[:-offset]
        r = predict_for_seq(window_data, offset, model)
        task = Task(window_data, history[-offset:], r[-offset:])
        tasks.append(task)
    return tasks

# %%
const_model_res = measure_on_all_train_data(ConstModel())

# %%
knn_model_res = measure_on_all_train_data(base_model)

# %%
c, const_model_scores = wmsfe(const_model_res)
k, knn_model_scores = wmsfe(knn_model_res)
print(c,k)
# Out:
# 0.2566049507498758 0.21156276892153902

# %%
len(const_model_scores)
# Out:
# 69

# %%
z_test(knn_model_scores, const_model_scores)
# Out:
# {'p_value': 0.33209327171823355,
#  'mu': 0.17148406701393296,
#  'sigma': 1.0459913225577846,
#  'win_rate': 0.5942028985507246}

# %%
loss, losses = wmsfe(tasks)
total([loss]), total(losses), loss, np.mean(losses)
# Out:
# (0.317097114369999,
#  0.6315122150302142,
#  0.21156276892153902,
#  0.21156276892153894)

# %%
T = 35
orig = train_data.values[:, T]
window_data = orig[:-offset]
r = predict_for_seq(window_data, offset)
plt.plot(r, 'red')
plt.plot(train_data.values[:, T], 'blue')
plt.show()
